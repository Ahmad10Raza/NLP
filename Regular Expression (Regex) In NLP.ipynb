# %% [markdown]
# # **Regular Expression: Regex**

# %% [markdown]
# # What is Regular Expression?
#
# A regular expression, often abbreviated as "regex" or "regexp," is a powerful tool for matching and manipulating text based on patterns. It is a sequence of characters that defines a search pattern. Regular expressions are commonly used for tasks such as searching, matching, and manipulating text or strings. They provide a flexible and concise way to specify patterns in text data. Here are some key aspects of regular expressions:
#
# 1. **Pattern Matching:** Regular expressions are primarily used for matching text based on a specified pattern. For example, you can use a regular expression to find all email addresses in a document or to search for words that follow a particular format.
#
# 2. **Wildcards and Metacharacters:** Regular expressions use special characters called metacharacters to represent patterns. For example, the dot (.) can match any character, and the asterisk (*) can represent zero or more occurrences of the preceding character or pattern.
#
# 3. **Character Classes:** Regular expressions allow you to specify character classes, such as [0-9] to match any digit or [A-Za-z] to match any uppercase or lowercase letter.
#
# 4. **Quantifiers:** Quantifiers specify how many times a character or group of characters should be repeated. For example, "x{2}" matches "xx," and "x{2,4}" matches "xx," "xxx," or "xxxx."
#
# 5. **Anchors:** Anchors are used to specify the position within a string where a match should occur. The caret (^) matches the start of a line, and the dollar sign ($) matches the end of a line.
#
# 6. **Alternation:** The pipe symbol (|) is used to specify alternatives. For example, "cat|dog" matches either "cat" or "dog."
#
# 7. **Groups and Capturing:** Parentheses () are used to group characters together and capture matched text. Captured text can be referenced or extracted.
#
# 8. **Escape Sequences:** Some characters, such as the dot (.) and asterisk (*), have special meanings in regular expressions. To match them literally, you need to escape them using a backslash (\).
#
# Regular expressions are widely used in various programming languages, text editors, and tools for tasks like searching and replacing text, data validation, and parsing. Learning to use regular expressions effectively can be a valuable skill for text processing and pattern matching in programming and data analysis.

# %% [markdown]
# # Patterns and Character In Regex.
#
# In regular expressions (regex or regexp), patterns are defined using a combination of ordinary characters, metacharacters, and character classes. These patterns are used to match and manipulate text based on specific criteria. Here are some common patterns and characters used in regex:
#
# 1. **Literal Characters:** Literal characters in a regex pattern match themselves. For example, the regex pattern "cat" matches the word "cat" in the text.
#
# 2. **Metacharacters:** Metacharacters are special characters in regex patterns that have meanings beyond their literal characters. Some common metacharacters include:
#    - `.` (Dot): Matches any single character except a newline.
#    - `*` (Asterisk): Matches zero or more occurrences of the preceding character or pattern.
#    - `+` (Plus): Matches one or more occurrences of the preceding character or pattern.
#    - `?` (Question Mark): Matches zero or one occurrence of the preceding character or pattern.
#    - `|` (Pipe): Specifies alternatives, allowing you to match one of several patterns.
#    - `()` (Parentheses): Groups characters or patterns together and creates capturing groups.
#    - `[]` (Square Brackets): Defines character classes, allowing you to match any character within the brackets.
#    - `{}` (Curly Braces): Specifies the number of occurrences of the preceding character or pattern.
#
# 3. **Character Classes:** Character classes allow you to specify a set of characters to match. Common character classes include:
#    - `[0-9]`: Matches any digit.
#    - `[A-Za-z]`: Matches any uppercase or lowercase letter.
#    - `[aeiou]`: Matches any of the specified vowels.
#    - `[^0-9]`: Matches any character that is not a digit.
#
# 4. **Anchors:** Anchors are used to specify the position within a string where a match should occur. Common anchors include:
#    - `^` (Caret): Matches the start of a line or string.
#    - `$` (Dollar Sign): Matches the end of a line or string.
#
# 5. **Escape Sequences:** Some characters have special meanings in regex and need to be escaped to match them literally. For example, to match a literal dot (.), you use `\.`.
#
# 6. **Quantifiers:** Quantifiers specify how many times a character or pattern should be repeated. Common quantifiers include:
#    - `{n}`: Matches exactly n occurrences.
#    - `{n,}`: Matches n or more occurrences.
#    - `{n,m}`: Matches between n and m occurrences.
#
# Here are some examples of regex patterns:
# - `\d{3}`: Matches exactly three digits.
# - `[A-Za-z]+`: Matches one or more uppercase or lowercase letters.
# - `^The`: Matches lines or strings that start with "The."
# - `\d{4}-\d{2}-\d{2}`: Matches date patterns like "2023-10-16."
#
# Regular expressions provide a powerful and flexible way to define and search for patterns in text. They are widely used in programming, text processing, and data validation tasks.

# %% [markdown]
# # Metacharacters and Escaping In Regex.
#
# Metacharacters and escaping are essential concepts in regular expressions (regex) that help define patterns for searching and manipulating text. Metacharacters are special characters in regex that have predefined meanings, and escaping allows you to use these metacharacters as literal characters in your pattern. Here's a more detailed explanation of both concepts:
#
# 1. Metacharacters:
#    Metacharacters are characters in regex that have special meanings and are used to specify certain types of matches or operations. They are not matched as literal characters but rather control the behavior of the regular expression engine. Some common metacharacters include:
#
#    - `.` (Dot): Matches any character except a newline.
#    - `*` (Asterisk): Matches zero or more occurrences of the preceding element.
#    - `+` (Plus): Matches one or more occurrences of the preceding element.
#    - `?` (Question Mark): Matches zero or one occurrence of the preceding element.
#    - `|` (Pipe): Acts as an OR operator, allowing you to specify alternatives.
#    - `^` (Caret): Matches the start of a line or string.
#    - `$` (Dollar): Matches the end of a line or string.
#    - `[ ]` (Square Brackets): Defines a character class for matching a single character from a set of characters.
#    - `{ }` (Curly Braces): Specifies the exact number of occurrences or a range of occurrences of the preceding element.
#    - `()` (Parentheses): Groups elements together and captures matched text.
#
# 2. Escaping:
#    Escaping is the process of preceding a metacharacter with a backslash `\` to indicate that you want to match that metacharacter as a literal character rather than as a special character with its regular meaning. For example, if you want to search for a literal dot (.) in a text, you need to escape it as `\.`.
#
#    Common metacharacters that often need escaping include:
#    - `.`
#    - `*`
#    - `+`
#    - `?`
#    - `|`
#    - `^`
#    - `$`
#    - `[`
#    - `]`
#    - `{`
#    - `}`
#    - `(`
#    - `)`
#    - `\` (Backslash)
#
#    Here's an example of using escaping in regex:
#
#    - `\.`: Matches a literal dot.
#    - `\*`: Matches a literal asterisk.
#    - `\(`: Matches a literal opening parenthesis.
#    - `\)` : Matches a literal closing parenthesis.
#
# Escaping is useful when you want to search for specific characters that are metacharacters in regex. It allows you to make your regex pattern more precise and avoid any unintended special behaviors.
#
# In summary, metacharacters have predefined meanings in regex, while escaping allows you to treat them as literal characters when needed. Understanding both concepts is crucial for effectively using regular expressions for pattern matching and text manipulation.

# %% [markdown]
# # Classes and Rangex
#
# Character classes and ranges in regular expressions (regex) are tools used to specify sets of characters you want to match. They allow you to create patterns that match characters within a defined group or range, making your regex patterns more concise and expressive. Here's an explanation of character classes and ranges in regex:
#
# 1. Character Classes:
#    A character class is a way to specify a set of characters that you want to match at a particular position in the text. Character classes are enclosed in square brackets `[ ]`, and any character inside the brackets will be considered a valid match. For example:
#
#    - `[aeiou]` matches any vowel (a, e, i, o, or u).
#    - `[0-9]` matches any digit from 0 to 9.
#    - `[A-Za-z]` matches any uppercase or lowercase letter.
#    - `[abc123]` matches either 'a', 'b', 'c', '1', '2', or '3'.
#
#    You can also use a caret `^` as the first character inside the brackets to negate the character class. For example, `[^aeiou]` matches any character that is not a vowel.
#
# 2. Ranges:
#    Ranges in regex allow you to specify a continuous range of characters in a character class. Ranges are indicated using a hyphen `-` between two characters inside the brackets. For example:
#
#    - `[0-9]` matches any digit from 0 to 9.
#    - `[A-Z]` matches any uppercase letter from 'A' to 'Z'.
#    - `[a-z]` matches any lowercase letter from 'a' to 'z'.
#    - `[A-Za-z0-9]` matches any alphanumeric character (letters and digits).
#
#    Ranges are a convenient way to simplify character class definitions when dealing with sequential or consecutive characters.
#
# Here are some more examples to illustrate character classes and ranges:
#
# - `[^0-9]` matches any character that is not a digit.
# - `[A-Fa-f0-9]` matches any character that is a hexadecimal digit (0-9 and A-F or a-f).
# - `[a-zA-Z_]` matches any letter (uppercase or lowercase) or underscore '_'.
#
# Character classes and ranges can make your regex patterns more concise and readable when you need to match specific groups of characters. They are an essential part of regular expressions and are frequently used to describe patterns in text matching and manipulation tasks.

# %% [markdown]
# # Quantifiers and Repetition
#
#
# **Quantifiers** in NLP are words and phrases that indicate the quantity of something. They can be used to describe the number of times something happens, the amount of something that exists, or the proportion of something that is true.
#
# Some examples of quantifiers in English include:
#
# * **Count quantifiers:** one, two, three, four, five, six, seven, eight, nine, ten, eleven, twelve, etc.
# * **Mass quantifiers:** some, any, much, little, all, most, none, etc.
# * **Proportional quantifiers:** many, few, half, most, all, some, none, etc.
#
# Quantifiers are important in NLP because they can help to identify the meaning and intent of text. For example, the sentence "I have a few cats" conveys a different meaning than the sentence "I have many cats." The first sentence suggests that the speaker has a small number of cats, while the second sentence suggests that the speaker has a large number of cats.
#
# Quantifiers can also be used to identify the parts of speech in a sentence. For example, the word "few" in the sentence "I have a few cats" is an adjective, while the word "three" in the sentence "I have three cats" is a numeral.
#
# **Repetition** in NLP is the occurrence of a word or phrase more than once in a text. Repetition can be used to emphasize a point, to create a rhythm or flow, or to signal a change in topic.
#
# Repetition can also be used to identify the structure of a sentence. For example, in the sentence "I love cats. I love dogs," the repetition of the word "I" indicates that the sentence is two separate sentences.
#
# Repetition can also be used to identify the meaning of a word or phrase. For example, in the sentence "She is very, very beautiful," the repetition of the word "very" emphasizes the speaker's belief that the woman is beautiful.
#
# Quantifiers and repetition are both important features of language. They can be used to convey meaning, to signal structure, and to create emphasis. NLP models need to be able to understand and process quantifiers and repetition in order to be able to accurately understand and generate text.
#
# Here are some examples of how quantifiers and repetition are used in NLP:
#
# * **Machine translation:** Quantifiers and repetition can be used to improve the accuracy of machine translation systems. For example, if a machine translation system is translating the sentence "I have a few cats" from English to Spanish, the system can use the quantifier "few" to identify the correct Spanish translation for the word "cats."
# * **Text summarization:** Quantifiers and repetition can be used to identify the most important information in a text and to generate a summary of that information. For example, if a text summarization system is summarizing a news article about a new product launch, the system can use quantifiers and repetition to identify the key features of the product and to generate a summary that highlights those features.
# * **Question answering:** Quantifiers and repetition can be used to improve the accuracy of question answering systems. For example, if a question answering system is asked the question "How many cats do you have?" the system can use the quantifier "many" to identify the correct answer.
#
# Overall, quantifiers and repetition are important features of language and NLP models need to be able to understand and process them in order to be able to accurately understand and generate text.

# %% [markdown]
# # Advanced Regex.
#
# Advanced regex techniques go beyond the basics of regular expressions to handle more complex and sophisticated pattern matching and text manipulation tasks. These techniques require a deeper understanding of regex and may involve more complex patterns, lookarounds, and other advanced features. Here are some advanced regex techniques:
#
# 1. Lookaheads and Lookbehinds:
#    Lookaheads and lookbehinds are zero-width assertions that allow you to check for patterns that are either ahead or behind the current position in the text, without consuming characters. These are useful for making sure that certain conditions are met before or after a match. Common lookaheads include positive lookahead `(?=...)`, negative lookahead `(?!...)`, positive lookbehind `(?<=...)`, and negative lookbehind `(?<!...)`.
#
# 2. Capturing and Non-Capturing Groups:
#    Regular expressions use parentheses to create capturing groups. In some cases, you may want to group expressions for logical purposes without capturing the matched text. You can create non-capturing groups using `(?:...)`. This can make your regex more efficient and cleaner when you don't need to access captured groups.
#
# 3. Backreferences:
#    Backreferences allow you to refer to previously captured groups in your regex pattern. This can be useful for matching repeated content, such as duplicated words or tags. To use a backreference, you reference a captured group with a backslash followed by the group number, like `\1` for the first capturing group.
#
# 4. Conditional Patterns:
#    Conditional patterns in regex allow you to define different matching conditions based on the presence or absence of specific substrings. This is often used to handle optional content or variations in text patterns.
#
# 5. Recursive Patterns:
#    Recursive patterns are used to match nested structures, like nested parentheses or HTML/XML tags. They are essential when working with hierarchical data formats.
#
# 6. Greedy and Lazy Quantifiers:
#    Greedy quantifiers, like `*` and `+`, match as much text as possible. Lazy quantifiers, denoted by `*?` and `+?`, match as little text as possible. Using these correctly is important to avoid overmatching or undermatching in your regex patterns.
#
# 7. Anchors and Word Boundaries:
#    Anchors such as `^` (start of line) and `$` (end of line) help ensure that your pattern matches only at specific positions in the text. Word boundaries `\b` or `\B` are used to match whole words or non-words, respectively.
#
# 8. Unicode and Character Properties:
#    Modern regex engines support Unicode properties, allowing you to match characters based on their Unicode properties like scripts, categories, and more. This is useful for working with multilingual text and complex character sets.
#
# 9. Recursion and Subroutine Calls:
#    Some regex engines support recursive patterns and subroutine calls, enabling you to write more complex patterns with nested structures and repeated subpatterns.
#
# Advanced regex techniques are valuable when dealing with intricate text processing tasks, but they also require a solid understanding of regex fundamentals and careful testing to ensure that the patterns work as expected. Mastery of these techniques can greatly enhance your ability to solve complex text manipulation problems using regular expressions.

# %% [markdown]
# # **Thank You!**
